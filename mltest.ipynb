# %%
import pandas
from IPython.display import display

a = pandas.read_csv("data.csv", skipinitialspace=True)
# display(a)
display(a[["CurrentPlayer", "CurrentPlayerWin"]])
display(
    a[["Depth", "CurrentPlayer", "CurrentPlayerWin"]]
    .groupby(["Depth", "CurrentPlayer"])
    .mean()
)

display(a[a["Depth"] == 16][[ "Board", "State", "CurrentPlayer", "CurrentPlayerWin"]].iloc[:10])
# Out:
#       CurrentPlayer  CurrentPlayerWin
# 0                 0                 0
# 1                 1                 1
# 2                 1                 0
# 3                 1                 0
# 4                 0                 0
# ...             ...               ...
# 3785              1                 1
# 3786              1                 1
# 3787              1                 1
# 3788              1                 1
# 3789              1                 1
#
# [3790 rows x 2 columns]
#                      CurrentPlayerWin
# Depth CurrentPlayer
# 15    0                      0.829960
#       1                      0.857708
# 16    0                      0.185675
#       1                      0.198964
#                 Board          State  CurrentPlayer  CurrentPlayerWin
# 0  0xC4DCAC95A46A24E4  0x6AC50E17079              0                 0
# 1  0xAC334D6874AB422E  0xAF0E0F6EE9C              1                 1
# ...
